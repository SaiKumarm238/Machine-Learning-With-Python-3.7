# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("bostonhousing.csv") # reading the data into df

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# Housing Values in Suburbs of Boston
# The medv variable is the target variable.
# Data description
# The Boston data frame has 506 rows and 14 columns.
# This data frame contains the following columns:
# - crim- per capita crime rate by town.
# - zn- proportion of residential land zoned for lots over 25,000 sq.ft.
# - indus
# proportion of non-retail business acres per town.
# - chas -
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# - nox -
# nitrogen oxides concentration (parts per 10 million).
# - rm -
# average number of rooms per dwelling.
# - age -
# proportion of owner-occupied units built prior to 1940.
# - dis -
# weighted mean of distances to five Boston employment centres.
# - rad -
# index of accessibility to radial highways.
# - tax -
# full-value property-tax rate per \$10,000.
# - ptratio -
# pupil-teacher ratio by town.
# - black -
# 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# - lstat -
# lower status of the population (percent).
# - medv -
# median value of owner-occupied homes in \$1000s.

# %%
# understanding the data 
df.head() #top 5 rows
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail() # last 5 rows
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
# features in the df
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 14

# %%
# shape of the columns
df.shape
# Out:
# (506, 14)

# %%
# row indices of the dataframe
df.index
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
# dtype of each and every columns
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
# info of the df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# crim       506 non-null float64
# zn         506 non-null float64
# indus      506 non-null float64
# chas       506 non-null int64
# nox        506 non-null float64
# rm         506 non-null float64
# age        506 non-null float64
# dis        506 non-null float64
# rad        506 non-null int64
# tax        506 non-null int64
# ptratio    506 non-null float64
# b          506 non-null float64
# lstat      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
## Missing value count column wise
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
# total no.of missing values in data frame
df.isna().sum().sum() # there is no missing values in given data frame
# Out:
# 0

# %%
# Description for Numerical Column 
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# cp-relition of the data frame
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
df.nunique()
# Out:
# crim       504
# zn          26
# indus       76
# chas         2
# nox         81
# rm         446
# age        356
# dis        412
# rad          9
# tax         66
# ptratio     46
# b          357
# lstat      455
# medv       229
# dtype: int64

# %%
# featues with numeric
num_cols = df.columns
num_cols
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# Draw the histogram for all the numerical columns
plt.figure(figsize=(10,100))
plt.subplots_adjust(hspace =0.5, wspace=0.5)
for i in range((len(num_cols))):
    plt.subplot(14,2,2*i+1)
    plt.hist(df[num_cols[i]])
    plt.title(num_cols[i]+"  Histogram")
    plt.subplot(14,2,2*i+2)
    plt.boxplot(df[num_cols[i]])
    plt.title(num_cols[i]+"  Subplot")

# %%
# converting the data in to normaly squade 
data = np.log1p(df)
data
# Out:
#          crim        zn     indus  chas       nox        rm       age  \
# 0    0.006300  2.944439  1.196948   0.0  0.430483  2.024853  4.192680
# 1    0.026944  0.000000  2.088153   0.0  0.384582  2.004314  4.380776
# 2    0.026924  0.000000  2.088153   0.0  0.384582  2.102303  4.128746
# 3    0.031857  0.000000  1.156881   0.0  0.377066  2.079192  3.845883
# 4    0.066770  0.000000  1.156881   0.0  0.377066  2.097650  4.010963
# ..        ...       ...       ...   ...       ...       ...       ...
# 501  0.060747  0.000000  2.559550   0.0  0.452985  2.027227  4.249923
# 502  0.044275  0.000000  2.559550   0.0  0.452985  1.962908  4.352855
# 503  0.058986  0.000000  2.559550   0.0  0.452985  2.076437  4.521789
# 504  0.103991  0.000000  2.559550   0.0  0.452985  2.053354  4.503137
# 505  0.046320  0.000000  2.559550   0.0  0.452985  1.950187  4.404277
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...

# %%
num_cols = data.columns
num_cols
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# Draw the histogram for all the numerical columns
plt.figure(figsize=(10,100))
plt.subplots_adjust(hspace =0.5, wspace=0.5)
for i in range((len(num_cols))):
    plt.subplot(14,2,2*i+1)
    plt.hist(df[num_cols[i]])
    plt.title(num_cols[i]+"  Histogram")
    plt.subplot(14,2,2*i+2)
    plt.boxplot(df[num_cols[i]])
    plt.title(num_cols[i]+"  Subplot")

# %% [markdown]
# # Apply the Linear regression for entire data

# %%
features = df.drop("medv", axis = 1)
target = df["medv"]

# %%
# Divide the data into tarining and testing for all the below problems
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(features,target)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
# Apply the Linear regression for entire data
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(x_train,y_train)
y_pred = LR.predict(x_test) 
y_pred
# Out:
# array([15.30515345, 18.21163648, 30.7249771 , 13.3369601 , 24.39137902,
#        20.86236086, 33.4093263 , 24.41170463, 14.5275987 , 22.419108  ,
#        26.54209236, 18.43909506, 20.25914151, 16.12645269, 25.12850116,
#        20.49186386, 16.98951141, 21.73052411, 25.35645925, 22.67946109,
#        25.0531926 , 22.75917496,  9.70483157, 21.19728943, 16.53316719,
#        25.10464254, 28.82510012, 36.0816747 , 21.49830923, 21.20684042,
#        14.47451366, 20.66057892, 20.76698717, 25.40932703, 28.54328649,
#        12.71842458, 17.88186344, 27.32539079, 30.66007831, 24.09136646,
#        24.15929762, 31.84536902, 18.66039145, 33.42474965, 15.86996879,
#        39.87631386, 24.70279847, 27.48062501, 27.9724843 , 17.24848856,
#        23.22751599, 19.7392387 , 31.03204399, 23.00574985, 20.42059083,
#        11.39094788, 22.37682565, 13.6714496 , 38.15338555, 23.76564156,
#        33.82869518, 22.16308774, 38.85344976, 20.6596891 , 13.20183823,
# ...

# %%
# Check the mse and r2score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
mse = mean_squared_error(y_pred,y_test)
print("the mean_squared_error is: ", mse)
r2 = r2_score(y_pred,y_test)
print("the r2_score_error is: ", r2)
# Out:
# the mean_squared_error is:  22.77454112844708
# the r2_score_error is:  0.5378808948241496

# %% [markdown]
# # Apply the Linear regression for entire data after applying the log1p

# %%
features_sq = data.drop("medv", axis = 1)
target_sq = data["medv"]

# %%
# Divide the data into tarining and testing for all the data applying the log1p
from sklearn.model_selection import train_test_split
x_train_sq,x_test_sq,y_train_sq,y_test_sq = train_test_split(features_sq,target_sq)
print(x_train_sq.shape)
print(y_train_sq.shape)
print(x_test_sq.shape)
print(y_test_sq.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
# Apply the Linear regression for entire data after applying the log1p
LR= LinearRegression()
LR.fit(x_train_sq,y_train_sq)
y_pred_sq = LR.predict(x_test_sq) 
y_pred_sq
# Out:
# array([3.43338793, 3.50233216, 3.14575612, 2.82894827, 3.06766493,
#        2.51140707, 2.46608187, 2.85960584, 3.50129074, 2.5610916 ,
#        2.77327807, 2.7384584 , 3.08681453, 3.53021172, 2.86960023,
#        2.99205668, 2.30061493, 3.613018  , 2.25049981, 3.46293699,
#        3.70827727, 2.83577734, 3.13111514, 2.49853389, 3.19808818,
#        2.83426093, 3.09087809, 3.86528339, 3.96353306, 3.25270646,
#        3.43627256, 3.35003045, 3.18438736, 3.11938069, 3.4545414 ,
#        2.52139962, 3.10708103, 2.95114239, 2.61059888, 2.82885924,
#        3.43008457, 3.07911276, 2.70483311, 3.29423883, 3.00307198,
#        3.19755737, 3.82616239, 2.61781698, 3.10600494, 3.60911976,
#        3.04419963, 3.2177841 , 3.2776781 , 3.16347509, 2.87215954,
#        2.94665882, 3.06351813, 3.45201524, 2.9625023 , 3.18599373,
#        3.02366384, 3.30452896, 2.66125517, 3.0998874 , 3.47202622,
#        3.58294138, 3.2304871 , 2.94783144, 3.3312194 , 2.91763531,
# ...

# %%
mse_sq = mean_squared_error(y_pred_sq,y_test_sq)
print("the mean_squared_error is: ", mse_sq)
r2_sq = r2_score(y_pred_sq,y_test_sq)
print("the r2_score_error is: ", r2_sq)
# Out:
# the mean_squared_error is:  0.03695327761894002
# the r2_score_error is:  0.7043162944457664

# %% [markdown]
# # Apply the Linear regression for entire data after scaling - MinMAxScaler

# %%
# Apply the Linear regression for entire data
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
df_mms = pd.DataFrame(MMS.fit_transform(df), columns=num_cols)
df_mms
# Out:
# C:\Users\saiku\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# ...

# %%
features_mms = df_mms.drop("medv", axis = 1)
target_mms = df_mms["medv"]

# %%
# Divide the data into tarining and testing
x_train_mms,x_test_mms,y_train_mms,y_test_mms = train_test_split(features_mms,target_mms)
print(x_train_mms.shape)
print(y_train_mms.shape)
print(x_test_mms.shape)
print(y_test_mms.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
# Applying the LinearRegression after scaleing the data
LR= LinearRegression()
LR.fit(x_train_mms,y_train_mms)
y_pred_mms = LR.predict(x_test_mms)
y_pred_mms
# Out:
# array([0.18415171, 0.49675663, 0.18499328, 0.35222106, 0.33137594,
#        0.45245355, 0.10460897, 0.38486818, 0.42540383, 0.49794908,
#        0.11473487, 0.3859687 , 0.53147917, 0.33019196, 0.62943301,
#        0.34331766, 0.59294149, 0.42585944, 0.32888287, 0.50665691,
#        0.36780728, 0.08017506, 0.50790146, 0.18939179, 0.20488158,
#        0.57815189, 0.50886814, 0.18083448, 0.61656475, 0.23311789,
#        0.49159745, 0.37014997, 0.33213291, 0.26818767, 0.39520777,
#        0.26067851, 0.25629932, 0.62133806, 0.4535541 , 0.40241398,
#        0.31994459, 0.62796011, 0.05127244, 0.23241151, 0.3830896 ,
#        0.60003572, 0.38542903, 0.39898611, 0.42178789, 0.72077281,
#        0.25331349, 0.33510848, 0.19190149, 0.50685635, 0.40600759,
#        0.46228436, 0.37631296, 0.31599584, 0.46204026, 0.39499132,
#        0.72413836, 0.25976461, 0.34445864, 0.58820821, 0.48952377,
#        0.27319599, 0.30840219, 0.74145806, 0.27784868, 0.66052935,
# ...

# %%
# Check the mse and r2score After scaleing 
mse_mms = mean_squared_error(y_pred_mms,y_test_mms)
print("the mean_squared_error is: ", mse_mms)
r2_mms = r2_score(y_pred_mms,y_test_mms)
print("the r2_score_error is: ", r2_mms)
# Out:
# the mean_squared_error is:  0.009646818191079879
# the r2_score_error is:  0.648051205909971

# %% [markdown]
# # Apply the Linear regression for entire data after scaling - StandardScaler

# %%
# Apply the Linear regression for entire data after scaling - StandardScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_sc = pd.DataFrame(sc.fit_transform(df), columns=num_cols)
df_sc
# Out:
# C:\Users\saiku\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\saiku\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#          crim        zn     indus      chas       nox        rm       age  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ...

# %%
features_sc = df_sc.drop("medv",axis = 1)
target_sc = df_sc["medv"]

# %%
features_sc
# Out:
#          crim        zn     indus      chas       nox        rm       age  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           dis       rad       tax   ptratio         b     lstat
# ...

# %%
target_sc
# Out:
# 0      0.159686
# 1     -0.101524
# 2      1.324247
# 3      1.182758
# 4      1.487503
#          ...
# 501   -0.014454
# 502   -0.210362
# 503    0.148802
# 504   -0.057989
# 505   -1.157248
# Name: medv, Length: 506, dtype: float64

# %%
# Divide the data into tarining and testing for StandardScaler
x_train_sc,x_test_sc,y_train_sc,y_test_sc = train_test_split(features_sc,target_sc)
print(x_train_sc.shape)
print(y_train_sc.shape)
print(x_test_sc.shape)
print(y_test_sc.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
# Applying the LinearRegression after scaleing the data
LR= LinearRegression()
LR.fit(x_train_sc,y_train_sc)
y_pred_sc = LR.predict(x_test_sc)
y_pred_sc
# Out:
# array([ 1.13987925, -0.23271609,  0.26860038,  1.22968793,  1.71177721,
#         0.10771588,  0.34497994,  0.77988343,  0.10598978, -0.28745235,
#        -1.59964307, -0.69932939,  0.01344193, -0.71160896, -0.2318573 ,
#        -0.16299881,  0.16774876, -1.47210833, -1.17541745, -0.82958853,
#         0.30749249,  1.94706615,  2.29431948,  0.04801039,  0.21334418,
#        -0.61591498,  0.30981121,  0.96074651,  0.99376692, -0.40672429,
#        -0.29354255, -0.39476157,  1.36384038, -0.44014769, -1.72221291,
#        -0.08183165, -0.46714159, -0.24234168, -0.20783033, -0.53004165,
#        -0.18030321,  0.47570452,  0.67592287,  0.03511963, -0.68996378,
#         1.52697908,  0.91385145,  0.14847398,  0.64909979, -0.62953321,
#        -0.35693114, -0.29628432,  0.96491371, -0.17372678,  1.36399218,
#        -0.9198312 ,  0.87352009, -0.39063947, -0.0261065 ,  0.93740899,
#         0.05884246, -1.1335379 ,  0.55103124,  0.831028  ,  1.5969233 ,
# ...

# %%
# Check the mse and r2score
mse_sc = mean_squared_error(y_pred_sc,y_test_sc)
print("the mean_squared_error is: ", mse_sc)
r2_sc = r2_score(y_pred_sc,y_test_sc)
print("the r2_score_error is: ", r2_sc)
# Out:
# the mean_squared_error is:  0.24976487398370323
# the r2_score_error is:  0.6298219548360345

# %%
# Take the top five features which has either positive or negative correlation with the medv
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # Take the top five features which has either positive or negative correlation with the medv

# %%
features_5= df.loc[:,["indus","dis","age","tax","ptratio"]]
target_5 = df["medv"]

# %%
x_train_5,x_test_5,y_train_5,y_test_5 = train_test_split(features_5,target_5)
print(x_train_5.shape)
print(y_train_5.shape)
print(x_test_5.shape)
print(y_test_5.shape)
# Out:
# (379, 5)
# (379,)
# (127, 5)
# (127,)

# %%
# Apply the Linear regression for those five columns data 
LR= LinearRegression()
LR.fit(x_train_5,y_train_5)
y_pred_5 = LR.predict(x_test_5) 
y_pred_5
# Out:
# array([32.63487133, 34.76187915, 24.21118666, 25.10985119, 23.49646104,
#        24.53914663, 28.03714639, 21.23704901, 16.54646122, 28.65170508,
#        18.3350634 , 15.08722826, 25.47178692, 29.38867905, 17.36037038,
#        23.88771854, 22.44394989, 23.61895018, 15.85110016, 24.65273427,
#        15.75090567, 25.37441801, 15.45598957, 24.76908087, 19.67898237,
#        25.10147644, 18.08236856, 23.4602134 , 15.28992994, 26.6669196 ,
#        15.56072364, 27.12730067, 15.18760254, 16.75170212, 25.67440397,
#        15.31144158, 25.73321871, 19.66333523, 24.87315491, 23.24563126,
#        25.10192684, 34.65515681, 28.91933122, 28.68871213, 23.4476525 ,
#        15.87247003, 26.45478231, 14.53497432, 26.32707142, 17.25577131,
#        27.65065915, 22.13867428, 17.37013573, 20.60516581, 20.84720394,
#        15.45735369, 15.56005984, 28.2580402 , 22.67925314, 34.27291987,
#        24.59040023, 21.36750895, 16.14129735, 27.66845027, 16.23698391,
# ...

# %%
# Check the mse and r2score
mse_5 = mean_squared_error(y_pred_5,y_test_5)
print("the mean_squared_error is: ", mse)
r2_5 = r2_score(y_pred_5,y_test_5)
print("the r2_score_error is: ", r2)
# Out:
# the mean_squared_error is:  22.77454112844708
# the r2_score_error is:  0.5378808948241496

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
features_5= df.loc[:,["crim","zn","rm","age","tax"]]
target_5 = df["medv"]

# %%
x_train_5,x_test_5,y_train_5,y_test_5 = train_test_split(features_5,target_5)
print(x_train_5.shape)
print(y_train_5.shape)
print(x_test_5.shape)
print(y_test_5.shape)
# Out:
# (379, 5)
# (379,)
# (127, 5)
# (127,)

# %%
# Apply the Linear regression for those five columns data 
LR= LinearRegression()
LR.fit(x_train_5,y_train_5)
y_pred_5 = LR.predict(x_test_5) 
y_pred_5
# Out:
# array([25.55994203, 28.31584454, 25.40144355, 27.45718279, 19.35150734,
#        10.86921055, 12.68710348, 20.05365389, 17.14521237, 41.13015921,
#        21.99134822, 20.96856211, 30.45978349, 26.09204694, 39.77577743,
#        20.64370605,  2.94245045, 12.75233621, 20.65389626, 15.1454349 ,
#        25.86576842, 19.0716418 ,  7.34526695, 19.06004443, 27.6276573 ,
#        27.98258557, 22.15176672, 33.05680786, 20.2959723 , 19.83837374,
#        41.86251363,  8.93020509, 16.0889909 , 19.57762099, 24.23176814,
#        18.77085946, 26.30219899, 30.97541098, 40.53897902, 31.340143  ,
#        11.49511161, 20.41743117, 27.7511406 , 19.6695797 , 17.71142138,
#        22.31249372, 21.70349786, 18.71763086, 30.67266746, 19.64556868,
#        32.80935345, 18.21212129, 26.94400972, 15.12491253, 17.59528239,
#        11.38777635, 17.25213016, 25.47411583, 32.26865897, 19.79148653,
#        19.49102359, 22.94163328, 25.21819064, 20.57616147, 25.07777947,
# ...

# %%
# Check the mse and r2score
mse_5 = mean_squared_error(y_pred_5,y_test_5)
print("the mean_squared_error is: ", mse)
r2_5 = r2_score(y_pred_5,y_test_5)
print("the r2_score_error is: ", r2)
# Out:
# the mean_squared_error is:  22.77454112844708
# the r2_score_error is:  0.5378808948241496

# %% [markdown]
# Select a dataset for regression
# Target should be continuous value
# Missing values
# replacing
# remove
# Don't replace the missing value in the target column
# Preprocessing
# Choose the featrures with highest correlation
# using only those features train the model and check the score
# Sepearate the features and target
# use the same model which you have used before.
# Apply all the regressor
# KNN
# Linear Regression
# Ridge
# Losso
# Elastic Net Regression
# Choose the best model and apply cross validation score. check the scores for each split
# By using RFE choose the 6 important features
# Apply any model and check the score
# compare the scores of best model and RFE and first model with hieghest correlated features

# %% [markdown]
# # Apply  the KNN regressor

# %%
x_train,x_test,y_train,y_test = train_test_split(features,target)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
# Applying the knn regressor on entair data
from sklearn.neighbors import KNeighborsRegressor
KNR = LinearRegression()
KNR.fit(x_train,y_train)
y_pred = KNR.predict(x_test) 
y_pred
# Out:
# array([23.84920641, 13.88849694, 16.96941035, 16.72997176, 23.7806076 ,
#        27.71802284, 20.96759399, 32.24318705, 27.47502379, 13.28508485,
#        11.52174433, 18.66005277, 21.96253557, 13.38005064, 15.19198856,
#        21.60069502, 10.08735717, 22.89016152, 17.78976895, 33.10025575,
#        31.53491185, 39.4284988 , 18.408907  , 13.92499473, 19.44255939,
#        18.64528666, 24.26957886, 32.52621335, 13.69694361,  7.96631541,
#        27.2080487 , 15.85787522, 15.54287152, 24.54314022, 16.54491029,
#        22.52437249, 36.87632721, 18.15277411, 11.64134314, 39.31844146,
#        31.09324317, 20.27807521, 28.77366828, 27.27988173, 19.76834861,
#        37.54195605, 36.96190091, 30.92893473, 28.18680034, 24.05021148,
#        34.51986646, 30.90623473, 21.11686854, 20.25735867, 17.40543492,
#         7.57444354, 21.10976132, 21.44948681, 20.05323229, 20.4627594 ,
#         7.95065646, 24.7070594 , 15.92961357, 32.80315243, 22.54096137,
# ...

# %%
# Check the mse and r2score
mse = mean_squared_error(y_pred,y_test)
print("the mean_squared_error is: ", mse)
r2 = r2_score(y_pred,y_test)
print("the r2_score_error is: ", r2)
# Out:
# the mean_squared_error is:  21.0411067403266
# the r2_score_error is:  0.6192036428067779

# %%
# fit with test data and predict with train data
KNR = LinearRegression()
KNR.fit(x_test,y_test)
y_pred = KNR.predict(x_train) 
y_pred
# Out:
# array([17.70198706, 26.14791942, 25.16166114, 18.83561024, 27.27524952,
#        17.59909958, 18.81955494, 27.38342831, 18.94747285, 13.71676426,
#         6.46609658, 19.31977148, 25.02748841, 12.78928578,  9.78610269,
#        24.83743759,  9.89732043, 38.59946379, 26.09497383, 13.00251122,
#        19.89690501, 35.63072232, 11.67520248, 13.65279392, 10.981819  ,
#        18.71139809, 36.06986275, 16.34732664, 20.60181544, 22.28070541,
#        27.58693089, 14.94315836, 16.28852474, 31.41317497, 29.29237529,
#        23.03523537, 31.46150985, 26.33619575, 27.84920344, 30.17399352,
#        16.29841564, 30.88335674, 34.90976797, 23.50352657, 13.27456334,
#        24.12080104, 13.41195754,  8.43520986, 19.49809381, 21.4459015 ,
#        25.79247991,  4.51650928,  5.90614751, 29.18092105, 19.09765971,
#        20.28022317, 34.38379088, 19.30491004, 29.0624844 , 21.38778971,
#        15.97871229, 14.51401733, 25.15776602, 21.05849297, 30.50543153,
# ...

# %%
# fit with test data and predict with train data error 
mse = mean_squared_error(y_pred,y_train)
print("the mean_squared_error is: ", mse)
r2 = r2_score(y_pred,y_train)
print("the r2_score_error is: ", r2)
# Out:
# the mean_squared_error is:  27.433191642678697
# the r2_score_error is:  0.5597529493799076

# %% [markdown]
# # Aplying the KNN Regression after applying the log1p

# %%
# Divide the data into tarining and testing for all the data applying the log1p
x_train_sq,x_test_sq,y_train_sq,y_test_sq = train_test_split(features_sq,target_sq)
print(x_train_sq.shape)
print(y_train_sq.shape)
print(x_test_sq.shape)
print(y_test_sq.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
# Apply the Linear regression for entire data after applying the log1p
KNR= KNeighborsRegressor()
KNR.fit(x_train_sq,y_train_sq)
y_pred_sq = KNR.predict(x_test_sq) 
y_pred_sq
# Out:
# array([2.79876366, 2.85344967, 3.05889768, 3.60594382, 3.20907032,
#        2.90255853, 3.08819423, 3.67686502, 3.28180302, 3.44423612,
#        3.58193983, 2.99212752, 3.342989  , 3.52572241, 3.51343564,
#        3.03294802, 3.51355843, 3.14397937, 3.19180476, 3.33567279,
#        3.22065697, 3.60827325, 2.87531665, 3.04856017, 3.03894204,
#        3.24240379, 2.98713973, 3.20225206, 3.01056718, 2.49178291,
#        2.75438355, 3.13835983, 3.08056347, 2.3279298 , 2.58607224,
#        3.3239195 , 3.66881512, 3.07924668, 2.70199061, 3.07397464,
#        2.88448171, 3.28368198, 3.07112424, 3.4485159 , 2.33313397,
#        2.51061669, 2.95219898, 2.51381106, 3.07005854, 3.09264662,
#        3.39124751, 2.88617556, 3.342989  , 3.28457201, 3.63547859,
#        3.06469049, 3.07618652, 3.06370711, 3.03799391, 3.63547859,
#        2.75515084, 3.24013366, 2.98713973, 2.58921154, 2.76995722,
#        3.07139942, 3.20225206, 3.07139942, 3.31603159, 2.55102877,
# ...

# %%
mse_sq = mean_squared_error(y_pred_sq,y_test_sq)
print("the mean_squared_error is: ", mse_sq)
r2_sq = r2_score(y_pred_sq,y_test_sq)
print("the r2_score_error is: ", r2_sq)
# Out:
# the mean_squared_error is:  0.029648279071182733
# the r2_score_error is:  0.6899394083072408

# %%
# fit with test data and predict with train data
KNR= KNeighborsRegressor()
KNR.fit(x_test_sq,y_test_sq)
y_pred_sq = KNR.predict(x_train_sq) 
y_pred_sq
# Out:
# array([2.72628932, 3.47540447, 3.02259887, 3.20967308, 2.50482332,
#        2.86964793, 2.75750518, 3.18478984, 3.07007851, 2.64369816,
#        3.00439553, 3.38640675, 3.15152087, 3.16157842, 3.28981979,
#        3.12615772, 3.14201857, 3.00439553, 3.05067765, 3.2119704 ,
#        2.64369816, 3.19064509, 2.69648053, 3.25541253, 2.87285001,
#        3.13307463, 3.18109669, 3.04984949, 2.89870501, 2.50482332,
#        3.01565251, 2.69648053, 3.41573494, 3.26096323, 3.2731418 ,
#        3.12804403, 2.93259482, 3.24747497, 3.32553654, 3.39587733,
#        3.03362391, 3.17793519, 3.14216627, 2.78540291, 2.89870501,
#        2.41739497, 2.77441666, 3.01819557, 3.14216627, 2.81619825,
#        3.10540194, 3.06717633, 3.08902142, 3.45562999, 3.24639562,
#        3.39587733, 3.05800241, 3.3309536 , 3.20939501, 2.78540291,
#        3.37108774, 3.44158062, 2.86597746, 2.93715211, 3.53512486,
#        2.84245992, 3.27691209, 3.41894952, 3.25181181, 3.09357117,
# ...

# %%
# fit with test data and predict with train data error 
mse_sq = mean_squared_error(y_pred_sq,y_train_sq)
print("the mean_squared_error is: ", mse_sq)
r2_sq = r2_score(y_pred_sq,y_train_sq)
print("the r2_score_error is: ", r2_sq)
# Out:
# the mean_squared_error is:  0.06010136683237016
# the r2_score_error is:  0.11819626056987331

# %% [markdown]
# # Aplying the Ridge Regression

# %%
from sklearn.linear_model import Ridge
for i in range (0,10,2):
    RR = Ridge(alpha=(i))
    RR.fit(x_train,y_train)
    y_pred = RR.predict(x_test)
    mse = mean_squared_error(y_pred,y_test)
    print("alpha =",i,"the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_test)
    print("alpha =",i,"the r2_score_error is: ", r2)
# Out:
# alpha = 0 the mean_squared_error is:  21.04110674032647
# alpha = 0 the r2_score_error is:  0.6192036428067802
# alpha = 2 the mean_squared_error is:  21.284102651209043
# alpha = 2 the r2_score_error is:  0.6060245678054792
# alpha = 4 the mean_squared_error is:  21.26550777751526
# alpha = 4 the r2_score_error is:  0.6041518264317817
# alpha = 6 the mean_squared_error is:  21.175610467903052
# alpha = 6 the r2_score_error is:  0.6043104742505777
# alpha = 8 the mean_squared_error is:  21.07720899197395
# alpha = 8 the r2_score_error is:  0.6049148732483844

# %%
# fit testing and traing data
for i in range (1,10,2):
    RR = Ridge(alpha=(i))
    RR.fit(x_test,y_test)
    y_pred = RR.predict(x_train)
    mse = mean_squared_error(y_pred,y_train)
    print("alpha =",i,"the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_train)
    print("alpha =",i,"the r2_score_error is: ", r2)
# Out:
# alpha = 1 the mean_squared_error is:  28.230831402221042
# alpha = 1 the r2_score_error is:  0.5453544305044948
# alpha = 3 the mean_squared_error is:  28.318683288091233
# alpha = 3 the r2_score_error is:  0.5395418059380246
# alpha = 5 the mean_squared_error is:  28.2945659951252
# alpha = 5 the r2_score_error is:  0.5356086558138508
# alpha = 7 the mean_squared_error is:  28.283596255225937
# alpha = 7 the r2_score_error is:  0.5318037331019652
# alpha = 9 the mean_squared_error is:  28.29322063413223
# alpha = 9 the r2_score_error is:  0.5279887803708914

# %%
from sklearn.model_selection import cross_val_score
for i in range(2,10):
    RR= Ridge()
    preds = cross_val_score(RR,features,target,cv =(i)) 
    print(i,"cross_val_score is", preds)
# Out:
# 2 cross_val_score is [ 0.59737247 -1.00058124]
# 3 cross_val_score is [ 0.65331631  0.55301152 -3.21831207]
# 4 cross_val_score is [ 0.63408956  0.60443638  0.36402473 -0.96395419]
# 5 cross_val_score is [ 0.66089569  0.74094893  0.62923672  0.08530169 -0.17029513]
# 6 cross_val_score is [ 0.6598744   0.68237875  0.54044616  0.79196621 -0.14712361 -0.01045059]
# 7 cross_val_score is [ 0.66334961  0.64863696  0.66419551  0.64012816  0.55094698 -0.31804537
#   0.35551163]
# 8 cross_val_score is [ 0.75457236  0.50387481  0.73070831  0.59964129  0.76818427 -0.36155992
#  -0.39253769  0.30058344]
# 9 cross_val_score is [ 0.74404409  0.54192693  0.6540861   0.58755731  0.67160028  0.71482878
#  -0.12842909 -0.59711125  0.34659392]

# %%
for i in range(2,10):
    RR= Ridge(alpha=(i))
    preds = cross_val_score(RR,features,target,cv =(i)) 
    print(i,"cross_val_score is", preds)
# Out:
# 2 cross_val_score is [ 0.59104148 -0.75284833]
# 3 cross_val_score is [ 0.65755898  0.55731996 -2.28323313]
# 4 cross_val_score is [ 0.64757624  0.60647528  0.37358438 -0.85305005]
# 5 cross_val_score is [ 0.67072778  0.73647305  0.65035523  0.11412158 -0.10927834]
# 6 cross_val_score is [ 0.66634164  0.68482506  0.55641499  0.79087046 -0.09641092 -0.02316941]
# 7 cross_val_score is [ 0.66560501  0.67128013  0.64261054  0.66282969  0.54176192 -0.2556353
#   0.29854021]
# 8 cross_val_score is [ 0.75026111  0.5574029   0.71303496  0.62020641  0.77037244 -0.29854259
#  -0.43098205  0.24204138]
# 9 cross_val_score is [ 0.73745722  0.58266138  0.66317307  0.58415593  0.69021233  0.70280805
#  -0.05450552 -0.64006228  0.28593558]

# %% [markdown]
# # Aplying the Losso Regression

# %%
from sklearn.linear_model import Lasso
for i in range (1,10,2):
    LSR = Lasso(alpha=(i))
    LSR.fit(x_train,y_train)
    y_pred = LSR.predict(x_test)
    mse = mean_squared_error(y_pred,y_test)
    print("alpha =",i,"the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_test)
    print("alpha =",i,"the r2_score_error is: ", r2)
# Out:
# alpha = 1 the mean_squared_error is:  23.166850051320477
# alpha = 1 the r2_score_error is:  0.5105765080130025
# alpha = 3 the mean_squared_error is:  28.337435753654503
# alpha = 3 the r2_score_error is:  0.34925244221839113
# alpha = 5 the mean_squared_error is:  30.340352465345667
# alpha = 5 the r2_score_error is:  0.24492981273701053
# alpha = 7 the mean_squared_error is:  30.839170675080652
# alpha = 7 the r2_score_error is:  0.1634860384711717
# alpha = 9 the mean_squared_error is:  31.718125213457196
# alpha = 9 the r2_score_error is:  0.06504808300256382

# %%
# fit testing and traing 
for i in range (1,10,2):
    LSR = Lasso(alpha=(i))
    LSR.fit(x_test,y_test)
    y_pred = LSR.predict(x_train)
    mse = mean_squared_error(y_pred,y_train)
    print("alpha =",i,"the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_train)
    print("alpha =",i,"the r2_score_error is: ", r2)
# Out:
# alpha = 1 the mean_squared_error is:  32.2802250650256
# alpha = 1 the r2_score_error is:  0.32034358017383235
# alpha = 3 the mean_squared_error is:  41.36957386559462
# alpha = 3 the r2_score_error is:  -0.08110830461915186
# alpha = 5 the mean_squared_error is:  43.35943952928663
# alpha = 5 the r2_score_error is:  -0.2454472014576361
# alpha = 7 the mean_squared_error is:  45.376067648303845
# alpha = 7 the r2_score_error is:  -0.4141877565431955
# alpha = 9 the mean_squared_error is:  47.03022476343371
# alpha = 9 the r2_score_error is:  -0.5722464729366423

# %%
for i in range(2,10):
    preds = cross_val_score(LSR,features,target,cv =(i)) 
    print(i,"cross_val_score is", preds)
# Out:
# 2 cross_val_score is [0.46621509 0.5182547 ]
# 3 cross_val_score is [ 0.32151845 -0.01495654  0.22198095]
# 4 cross_val_score is [0.1293664  0.31565388 0.17451871 0.16525672]
# 5 cross_val_score is [0.21443958 0.50386188 0.00966192 0.30793303 0.37745145]
# 6 cross_val_score is [0.09567543 0.47853279 0.07705159 0.24866942 0.355148   0.42423764]
# 7 cross_val_score is [ 0.16862145  0.50809508  0.22806393 -0.07967417 -0.34350534  0.38232601
#   0.46255885]
# 8 cross_val_score is [ 0.23321836  0.30136777  0.45261895  0.15893487  0.13100366 -0.11701102
#  -0.11134618  0.39484471]
# 9 cross_val_score is [ 0.30170466  0.1859085   0.46185346  0.0330122  -0.07603612  0.22569546
#   0.22848011 -0.12432052  0.3451716 ]

# %% [markdown]
# # Applying the Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
# fit traing and testing
for i in range (1,10,2):
    ENR = ElasticNet(alpha=(i),l1_ratio=(i)/2)
    ENR.fit(x_train,y_train)
    y_pred = ENR.predict(x_test)
    mse = mean_squared_error(y_pred,y_test)
    print("alpha =",i,"the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_test)
    print("alpha =",i,"the r2_score_error is: ", r2)
# Out:
# alpha = 1 the mean_squared_error is:  22.651294557874426
# alpha = 1 the r2_score_error is:  0.5269369442172724
# alpha = 3 the mean_squared_error is:  30.252538984248098
# alpha = 3 the r2_score_error is:  0.30207136861669504
# alpha = 5 the mean_squared_error is:  31.357401778681442
# alpha = 5 the r2_score_error is:  0.1335343943816658
# alpha = 7 the mean_squared_error is:  37.70775965260162
# alpha = 7 the r2_score_error is:  -0.6142690677699436
# alpha = 9 the mean_squared_error is:  54.48941941046821
# alpha = 9 the r2_score_error is:  -1.7983581812695633

# %%
# fit testing and traing 
for i in range (1,10,2):
    ENR =ElasticNet(alpha=(i),l1_ratio=(i)/2)
    ENR.fit(x_test,y_test)
    y_pred = ENR.predict(x_train)
    mse = mean_squared_error(y_pred,y_train)
    print("alpha =",i,"the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_train)
    print("alpha =",i,"the r2_score_error is: ", r2)
# Out:
# alpha = 1 the mean_squared_error is:  31.677793925539753
# alpha = 1 the r2_score_error is:  0.3579236159061937
# alpha = 3 the mean_squared_error is:  42.357751153259535
# alpha = 3 the r2_score_error is:  -0.1410753328286758
# alpha = 5 the mean_squared_error is:  46.61638679599146
# alpha = 5 the r2_score_error is:  -0.5369925830237066
# alpha = 7 the mean_squared_error is:  56.64973121281645
# alpha = 7 the r2_score_error is:  -1.7595526876669667
# alpha = 9 the mean_squared_error is:  71.93834979762605
# alpha = 9 the r2_score_error is:  -3.6827182252546278

# %%
for i in range(2,10):
    preds = cross_val_score(ENR,features,target,cv =(i)) 
    print(i,"cross_val_score is", preds)
# Out:
# 2 cross_val_score is [0.05532521 0.29969393]
# 3 cross_val_score is [-0.37349915 -0.49863046  0.04898624]
# 4 cross_val_score is [-0.78108574 -0.05319372 -0.17485632 -1.47675895]
# 5 cross_val_score is [-0.36783481  0.09632044 -0.41757035 -0.0123701  -0.0660404 ]
# 6 cross_val_score is [-0.68671693  0.00830206 -0.43149421 -0.01821308  0.05246038  0.18029497]
# 7 cross_val_score is [-0.67426439 -0.22901446 -0.19680819 -0.49235739 -0.2226767   0.02153238
#   0.14852006]
# 8 cross_val_score is [-0.71018101 -0.13495816  0.12467708 -0.35472529 -0.22401022 -0.5748617
#  -1.80196841  0.00841137]
# 9 cross_val_score is [-0.68324605  0.06474845 -0.05912551 -0.43459154 -0.50474003  0.07772499
#  -0.11773428 -1.36687692 -0.13891018]

# %% [markdown]
# # By using RFE choose the 6 important features

# %%
li = [LR,RR,LSR,ENR]

# %%
from sklearn.feature_selection import RFE
for i in li:
    print("est =", i)
    print()
    rfeMo = RFE(i,n_features_to_select=6)
    rfeMo = rfeMo.fit(x_train,y_train)
    y_pred = rfeMo.predict(x_test)
    mse = mean_squared_error(y_pred,y_test)
    print("the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_test)
    print("the r2_score_error is: ", r2)
    print()
# Out:
# est = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# the mean_squared_error is:  23.092777957597164
# the r2_score_error is:  0.585007537163429
#
# est = Ridge(alpha=9, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
#
# the mean_squared_error is:  23.74547783386786
# the r2_score_error is:  0.5586660112616919
#
# est = Lasso(alpha=9, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
#
# the mean_squared_error is:  31.71786639605007
# the r2_score_error is:  0.06506416896918021
#
# est = ElasticNet(alpha=9, copy_X=True, fit_intercept=True, l1_ratio=4.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
#
# ...

# %%
# fit test with train data
for i in li:
    print("est =", i)
    print()
    rfeMo = RFE(i,n_features_to_select=6)
    rfeMo = rfeMo.fit(x_test,y_test)
    y_pred = rfeMo.predict(x_train)
    mse = mean_squared_error(y_pred,y_train)
    print("the mean_squared_error is: ", mse)
    r2 = r2_score(y_pred,y_train)
    print("the r2_score_error is: ", r2)
    print()
# Out:
# est = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# the mean_squared_error is:  27.266916405030006
# the r2_score_error is:  0.5174583370748005
#
# est = Ridge(alpha=9, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
#
# the mean_squared_error is:  29.330632834638294
# the r2_score_error is:  0.4374797575892927
#
# est = Lasso(alpha=9, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
#
# the mean_squared_error is:  47.03024216461068
# the r2_score_error is:  -0.5722451760031395
#
# est = ElasticNet(alpha=9, copy_X=True, fit_intercept=True, l1_ratio=4.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
#
# ...

# %%
KNR= KNeighborsRegressor(n_neighbors=7)
rfeMo = RFE(KNR,n_features_to_select=6)
rfeMo = rfeMo.fit(x_train,y_train)
y_pred = rfeMo.predict(x_test)
mse = mean_squared_error(y_pred,y_test)
print("the mean_squared_error is: ", mse)
r2 = r2_score(y_pred,y_test)
print("the r2_score_error is: ", r2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-91-8b0aa948d95c> in <module>
#       1 KNR= KNeighborsRegressor(n_neighbors=7)
#       2 rfeMo = RFE(KNR,n_features_to_select=6)
# ----> 3 rfeMo = rfeMo.fit(x_train,y_train)
#       4 y_pred = rfeMo.predict(x_test)
#       5 mse = mean_squared_error(y_pred,y_test)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\rfe.py in fit(self, X, y)
#     138             The target values.
#     139         """
# --> 140         return self._fit(X, y)
#     141
#     142     def _fit(self, X, y, step_score=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\rfe.py in _fit(self, X, y, step_score)
#     185                 coefs = getattr(estimator, 'feature_importances_', None)
#     186             if coefs is None:
# ...

# %% [markdown]
# # BEST IS ELASTIC NET REGESSION
